# %% [markdown]
# <a href="https://colab.research.google.com/github/VAMSHINEELAMMA/SAMSUNG-INNOVATION-CAMPUS/blob/main/KMeans2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
datalink='/content/drive/MyDrive/0.Samsung CSR AIML/Resources/SIC-Artificial-Intelligence/SIC_AI_Coding_Exercises/SIC_AI_Chapter_05_Coding_Exercises/Clustering_mushroom.csv'

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(datalink)

df.head()
# Out:
#    poisonous  cap_shape_eq_convex  cap_shape_eq_bell  cap_shape_eq_sunken  \
# 0          1                    1                  0                    0
# 1          0                    1                  0                    0
# 2          0                    0                  1                    0
# 3          1                    1                  0                    0
# 4          0                    1                  0                    0
#
#    cap_shape_eq_flat  cap_shape_eq_knobbed  cap_shape_eq_conical  \
# 0                  0                     0                     0
# 1                  0                     0                     0
# 2                  0                     0                     0
# 3                  0                     0                     0
# 4                  0                     0                     0
#
#    cap_surface_eq_smooth  cap_surface_eq_scaly  cap_surface_eq_fibrous  ...  \
# ...

# %%
df.shape
# Out:
# (8124, 114)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Columns: 114 entries, poisonous to habitat_eq_leaves
# dtypes: int64(114)
# memory usage: 7.1 MB

# %%
cluster = KMeans(n_clusters=3, random_state=0)

cluster.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
cluster.fit_predict(df)
# Out:
# array([1, 1, 1, ..., 1, 2, 1], dtype=int32)

# %%
df['cluster'] = cluster.fit_predict(df)

df.head()
# Out:
#    poisonous  cap_shape_eq_convex  cap_shape_eq_bell  cap_shape_eq_sunken  \
# 0          1                    1                  0                    0
# 1          0                    1                  0                    0
# 2          0                    0                  1                    0
# 3          1                    1                  0                    0
# 4          0                    1                  0                    0
#
#    cap_shape_eq_flat  cap_shape_eq_knobbed  cap_shape_eq_conical  \
# 0                  0                     0                     0
# 1                  0                     0                     0
# 2                  0                     0                     0
# 3                  0                     0                     0
# 4                  0                     0                     0
#
#    cap_surface_eq_smooth  cap_surface_eq_scaly  cap_surface_eq_fibrous  ...  \
# ...

# %%
df['cluster'].value_counts()
# Out:
# cluster
# 1    5060
# 2    1768
# 0    1296
# Name: count, dtype: int64

# %%
df['cluster'].value_counts().hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
df['cluster'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cluster'>

# %%
sns.boxplot(x=df['poisonous'],y=df['cap_shape_eq_convex'])
# Out:
# <Axes: xlabel='poisonous', ylabel='cap_shape_eq_convex'>
